# %% [markdown]
# # SOTA 모델 CAR
# * https://github.com/sunwj/CAR.git 에서 CAR코드 다운.
# * https://mega.nz/file/XzIm3YhT#jbIOOOGBOiKtv3VAOD782Mz7nK1L_kma-BzR-RhboW4 에서 Pre-trained-models을 다운받아 CAR에 넣어줘야함.

# %%
# 경로 CAR로 맞추기
# %cd /content/drive/Shareddrives/msmg/level1/upsampling/upsampled_car/CAR

# %%
# %cd adaptive_gridsampler
# !python3 setup.py build_ext --inplace

# %%
# 경로 CAR로 다시 맞추기
# %cd /content/drive/Shareddrives/msmg/level1/upsampling/upsampled_car/CAR

# %%
# img_dir = 이미지 업로드 폴더, model_dir = pre-trained models 경로, output_dir = 이미지 저장 폴더

# !python3 run.py --scale 2 --img_dir /content/ --model_dir /content/ \
--output_dir /content/
