# %% [markdown]
# ## image, label 파일 목록 list에 저장

# %%
# !rm -rf /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/*.txt

# %%
import os
 
img_root_dir = '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/image'
label_root_dir = '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/label'
img_path_list = []
label_path_list = []

possible_img_extension = ['.png'] # 이미지 확장자
possible_label_extension = ['.json'] # 라벨 확장자
 
for (root, dirs, files) in os.walk(img_root_dir):
    if len(files) > 0:
        for file_name in files:
            if os.path.splitext(file_name)[1] in possible_img_extension:
                img_path = root + '/' + file_name
                
                # 경로에서 \를 모두 /로 바꿔줘야함
                img_path = img_path.replace('\\', '/') # \는 \\로 나타내야함         
                img_path_list.append(img_path)
                img_path_list.sort()

for (root, dirs, files) in os.walk(label_root_dir):
    if len(files) > 0:
        for file_name in files:
            if os.path.splitext(file_name)[1] in possible_label_extension:
                label_path = root + '/' + file_name
                
                # 경로에서 \를 모두 /로 바꿔줘야함
                label_path = label_path.replace('\\', '/') # \는 \\로 나타내야함         
                label_path_list.append(label_path)
                label_path_list.sort()
                             
print(img_path_list)
print(label_path_list)
# Out:
# ['/content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00007_PS3_K3A_NIA0276.png', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00010_PS3_K3A_NIA0276.png', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00031_PS3_K3A_NIA0276.png', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00033_PS3_K3A_NIA0276.png', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00048_PS3_K3A_NIA0276.png', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00051_PS3_K3A_NIA0276.png', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00054_PS3_K3A_NIA0276.png', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00080_PS3_K3A_NIA0276.png', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00084_PS3_K3A_NIA0276.png', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00096_PS3_K3A_NIA0276.png', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00101_PS3_K3A_NIA0276.png', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00126_PS3_K3A_NIA0276.png', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00134_PS3_K3A_NIA0276.png', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00145_PS3_K3A_NIA0276.png', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00148_PS3_K3A_NIA0276.png', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00155_PS3_K3A_NIA0276.png', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00174_PS3_K3A_NIA0276.png', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00175_PS3_K3A_NIA0276.png', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00201_PS3_K3A_NIA0276.png', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00202_PS3_K3A_NIA0276.png', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00220_PS3_K3A_NIA0276.png', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00226_PS3_K3A_NIA0276.png', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00236_PS3_K3A_NIA0276.png', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00242_PS3_K3A_NIA0276.png', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00248_PS3_K3A_NIA0276.png', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00272_PS3_K3A_NIA0276.png', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00283_PS3_K3A_NIA0276.png', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00288_PS3_K3A_NIA0276.png', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00309_PS3_K3A_NIA0276.png', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00333_PS3_K3A_NIA0276.png', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00338_PS3_K3A_NIA0276.png', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00410_PS3_K3A_NIA0276.png', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00576_PS3_K3A_NIA0277.png', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00592_PS3_K3A_NIA0277.png', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00595_PS3_K3A_NIA0277.png', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00618_PS3_K3A_NIA0277.png', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00621_PS3_K3A_NIA0277.png', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BL ...
# ['/content/drive/Shareddrives/msmg/level1/dataset/validation/building/label/BLD00007_PS3_K3A_NIA0276.json', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/label/BLD00010_PS3_K3A_NIA0276.json', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/label/BLD00031_PS3_K3A_NIA0276.json', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/label/BLD00033_PS3_K3A_NIA0276.json', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/label/BLD00048_PS3_K3A_NIA0276.json', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/label/BLD00051_PS3_K3A_NIA0276.json', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/label/BLD00054_PS3_K3A_NIA0276.json', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/label/BLD00080_PS3_K3A_NIA0276.json', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/label/BLD00084_PS3_K3A_NIA0276.json', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/label/BLD00096_PS3_K3A_NIA0276.json', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/label/BLD00101_PS3_K3A_NIA0276.json', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/label/BLD00126_PS3_K3A_NIA0276.json', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/label/BLD00134_PS3_K3A_NIA0276.json', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/label/BLD00145_PS3_K3A_NIA0276.json', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/label/BLD00148_PS3_K3A_NIA0276.json', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/label/BLD00155_PS3_K3A_NIA0276.json', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/label/BLD00174_PS3_K3A_NIA0276.json', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/label/BLD00175_PS3_K3A_NIA0276.json', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/label/BLD00201_PS3_K3A_NIA0276.json', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/label/BLD00202_PS3_K3A_NIA0276.json', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/label/BLD00220_PS3_K3A_NIA0276.json', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/label/BLD00226_PS3_K3A_NIA0276.json', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/label/BLD00236_PS3_K3A_NIA0276.json', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/label/BLD00242_PS3_K3A_NIA0276.json', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/label/BLD00248_PS3_K3A_NIA0276.json', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/label/BLD00272_PS3_K3A_NIA0276.json', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/label/BLD00283_PS3_K3A_NIA0276.json', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/label/BLD00288_PS3_K3A_NIA0276.json', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/label/BLD00309_PS3_K3A_NIA0276.json', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/label/BLD00333_PS3_K3A_NIA0276.json', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/label/BLD00338_PS3_K3A_NIA0276.json', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/label/BLD00410_PS3_K3A_NIA0276.json', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/label/BLD00576_PS3_K3A_NIA0277.json', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/label/BLD00592_PS3_K3A_NIA0277.json', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/label/BLD00595_PS3_K3A_NIA0277.json', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/label/BLD00618_PS3_K3A_NIA0277.json', '/content/drive/Shareddrives/msmg/level1/dataset/validation/building/label/BLD00621_PS3_K3A_NIA0277.json', '/content/drive/Shareddrives/msmg/level1 ...

# %%
# 파일 개수 확인
print(len(img_path_list))
print(len(label_path_list))
# Out:
# 159
# 159

# %%
def get_polygon_xy(ann_seg):
    polygon_x = [x for index, x in enumerate(ann_seg) if index % 2 == 0]
    polygon_y = [x for index, x in enumerate(ann_seg) if index % 2 == 1]
    polygon_xy = [[x, y] for x, y in zip(polygon_x, polygon_y)]
    polygon_xy = np.array(polygon_xy, np.int32)
    
    return polygon_xy

# %%
def apply_mask2(image, mask):
    image[:, :] = np.where(mask == 1, image[:, :] + 1, image[:, :])
    
    return image

# %%
def get_mask2(image_array_shape, polygon_xy):
    ## polygon 정보를 mask 정보로 변환. 
    zero_mask = np.zeros(image_array_shape) # mask 정보는 2차원 선호
    masked_polygon = cv2.fillPoly(zero_mask, [polygon_xy], 1)

    return masked_polygon

# %%
# ann_seg_list에 있는 object들의 segmentation에 따라 instance segmentation 시각화. 
def draw_segment2(image_array, ann_seg_list, color_list, alpha):
    draw_image = image_array.copy()
    mask_array_shape = draw_image.shape[0:2]
    zero_mask = np.zeros(mask_array_shape)
    masked_image = zero_mask    # 지역변수 초기화

    # list형태로 입력된 segmentation 정보들을 각각 시각화
    for index, ann_seg in enumerate(ann_seg_list):
        # polygon 좌표로 변환. 
        polygon_xy = get_polygon_xy(ann_seg)

        # mask 정보 변환
        masked_polygon = get_mask2(mask_array_shape, polygon_xy)
        
        # masking 적용. 
        masked_image = apply_mask2(zero_mask, masked_polygon)

    return masked_image

# %% [markdown]
# ## 건물 (컨테이너 박스와 기타 2개 class 제외) masking 정보가 담긴 txt 파일 생성

# %%
import matplotlib.pyplot as plt
import cv2
import json
import numpy as np

green_color = (0, 255, 0)
color_list = [
              (0, 255, 0),
              (255, 0, 0),
              (0, 0, 255)
]

for i, j in zip(img_path_list, label_path_list):

    # 원본 이미지 시각화 
    image_array = cv2.cvtColor(cv2.imread(i), cv2.COLOR_BGR2RGB)
    with open(j) as json_file:
        data_infos = json.load(json_file)

    ann_seg_list = [] # 빈 리스트 생성
    for k in range(len(data_infos['features'])):  # 이미지 내 폴리곤 개수만큼 반복
        imcoords = []
        # 건물 class가 '기타'거나 '컨테이너 박스'일 경우는 제외
        if data_infos['features'][k]['properties']['type_name'] == "\uae30\ud0c0" or data_infos['features'][k]['properties']['type_name'] == "\ucee8\ud14c\uc774\ub108 \ubc15\uc2a4":
            continue
        # 건물의 polygon 좌표가 없을 경우 제외
        if data_infos['features'][k]['properties']['building_imcoords'] == "":
            continue
        imcoords = list(map(float, data_infos['features'][k]['properties']['building_imcoords'].split(',')))

        ann_seg_list.append(imcoords)
    
    masked_image = draw_segment2(image_array, ann_seg_list, color_list, alpha=0.6)
    masked_image[masked_image > 1] = 1
    masked_image.astype(int)
    np.savetxt(i.replace('.png', '.txt'), masked_image, fmt = '%d', delimiter = ' ')
    print(i)
# Out:
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00007_PS3_K3A_NIA0276.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00010_PS3_K3A_NIA0276.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00031_PS3_K3A_NIA0276.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00033_PS3_K3A_NIA0276.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00048_PS3_K3A_NIA0276.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00051_PS3_K3A_NIA0276.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00054_PS3_K3A_NIA0276.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00080_PS3_K3A_NIA0276.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00084_PS3_K3A_NIA0276.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00096_PS3_K3A_NIA0276.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00101_PS3_K3A_NIA0276.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00126_PS3_K3A_NIA0276.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00134_PS3_K3A_NIA0276.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00145_PS3_K3A_NIA0276.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00148_PS3_K3A_NIA0276.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00155_PS3_K3A_NIA0276.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00174_PS3_K3A_NIA0276.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00175_PS3_K3A_NIA0276.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00201_PS3_K3A_NIA0276.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00202_PS3_K3A_NIA0276.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00220_PS3_K3A_NIA0276.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00226_PS3_K3A_NIA0276.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00236_PS3_K3A_NIA0276.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00242_PS3_K3A_NIA0276.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00248_PS3_K3A_NIA0276.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00272_PS3_K3A_NIA0276.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00283_PS3_K3A_NIA0276.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00288_PS3_K3A_NIA0276.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00309_PS3_K3A_NIA0276.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00333_PS3_K3A_NIA0276.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00338_PS3_K3A_NIA0276.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00410_PS3_K3A_NIA0276.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00576_PS3_K3A_NIA0277.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00592_PS3_K3A_NIA0277.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00595_PS3_K3A_NIA0277.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00618_PS3_K3A_NIA0277.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00621_PS3_K3A_NIA0277.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00641_PS3_K3A_NIA0277.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00652_PS3_K3A_NIA0277.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00682_PS3_K3A_NIA0277.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00697_PS3_K3A_NIA0277.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00710_PS3_K3A_NIA0277.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00712_PS3_K3A_NIA0277.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00768_PS3_K3A_NIA0277.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00769_PS3_K3A_NIA0277.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00770_PS3_K3A_NIA0277.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00793_PS3_K3A_NIA0277.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00794_PS3_K3A_NIA0277.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00811_PS3_K3A_NIA0277.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00840_PS3_K3A_NIA0277.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00843_PS3_K3A_NIA0277.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00854_PS3_K3A_NIA0277.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00871_PS3_K3A_NIA0277.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00872_PS3_K3A_NIA0277.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00925_PS3_K3A_NIA0277.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00943_PS3_K3A_NIA0277.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00945_PS3_K3A_NIA0277.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00948_PS3_K3A_NIA0277.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00961_PS3_K3A_NIA0277.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00964_PS3_K3A_NIA0277.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00978_PS3_K3A_NIA0277.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00981_PS3_K3A_NIA0277.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00989_PS3_K3A_NIA0277.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD00994_PS3_K3A_NIA0277.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD01002_PS3_K3A_NIA0277.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD01004_PS3_K3A_NIA0277.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD01037_PS3_K3A_NIA0277.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD01070_PS3_K3A_NIA0277.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD01071_PS3_K3A_NIA0277.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD01125_PS3_K3A_NIA0277.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD01141_PS3_K3A_NIA0277.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD01144_PS3_K3A_NIA0373.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD01146_PS3_K3A_NIA0373.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD01232_PS3_K3A_NIA0373.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD01247_PS3_K3A_NIA0373.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD01301_PS3_K3A_NIA0373.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD01392_PS3_K3A_NIA0373.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD01444_PS3_K3A_NIA0373.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD01446_PS3_K3A_NIA0373.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD01457_PS3_K3A_NIA0373.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD01501_PS3_K3A_NIA0373.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD01502_PS3_K3A_NIA0373.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD01545_PS3_K3A_NIA0373.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD01548_PS3_K3A_NIA0373.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD01552_PS3_K3A_NIA0373.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD01556_PS3_K3A_NIA0373.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD01557_PS3_K3A_NIA0373.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD01600_PS3_K3A_NIA0373.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD01603_PS3_K3A_NIA0373.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD01660_PS3_K3A_NIA0373.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD01711_PS3_K3A_NIA0373.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD01760_PS3_K3A_NIA0373.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD01862_PS3_K3A_NIA0374.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD01975_PS3_K3A_NIA0374.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD02014_PS3_K3A_NIA0374.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD02065_PS3_K3A_NIA0374.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD02066_PS3_K3A_NIA0374.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD02116_PS3_K3A_NIA0374.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD02125_PS3_K3A_NIA0374.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD02132_PS3_K3A_NIA0374.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD02179_PS3_K3A_NIA0374.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD02180_PS3_K3A_NIA0374.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD02224_PS3_K3A_NIA0374.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD02268_PS3_K3A_NIA0374.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD02274_PS3_K3A_NIA0374.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD02281_PS3_K3A_NIA0374.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD02285_PS3_K3A_NIA0374.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD02423_PS3_K3A_NIA0375.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD02444_PS3_K3A_NIA0375.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD02490_PS3_K3A_NIA0375.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD02491_PS3_K3A_NIA0375.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD02499_PS3_K3A_NIA0375.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD02545_PS3_K3A_NIA0375.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD02602_PS3_K3A_NIA0375.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD02762_PS3_K3A_NIA0375.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD02875_PS3_K3A_NIA0375.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD03311_PS3_K3A_NIA0376.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD03331_PS3_K3A_NIA0376.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD03367_PS3_K3A_NIA0376.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD03444_PS3_K3A_NIA0376.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD03532_PS3_K3A_NIA0376.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD03551_PS3_K3A_NIA0376.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD03693_PS3_K3A_NIA0376.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD03702_PS3_K3A_NIA0376.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD04051_PS3_K3A_NIA0377.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD04402_PS3_K3A_NIA0378.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD04404_PS3_K3A_NIA0378.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD04430_PS3_K3A_NIA0378.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD05519_PS3_K3A_NIA0380.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD05866_PS3_K3A_NIA0380.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD06235_PS3_K3A_NIA0381.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD06236_PS3_K3A_NIA0381.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD06604_PS3_K3A_NIA0381.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD07666_PS3_K3A_NIA0383.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD08377_PS3_K3A_NIA0384.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD08398_PS3_K3A_NIA0384.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD09836_PS3_K3A_NIA0387.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD09838_PS3_K3A_NIA0387.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD10664_PS3_K3A_NIA0389.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD10921_PS3_K3A_NIA0389.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD11632_PS3_K3A_NIA0390.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD11633_PS3_K3A_NIA0390.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/BLD12346_PS3_K3A_NIA0391.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/OBJ00176_PS3_K3_NIA0081.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/OBJ00352_PS3_K3_NIA0083.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/OBJ00878_PS3_K3_NIA0089.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/OBJ01050_PS3_K3_NIA0089.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/OBJ01226_PS3_K3_NIA0089.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/OBJ01573_PS3_K3_NIA0096.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/OBJ01576_PS3_K3_NIA0096.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/OBJ02101_PS3_K3_NIA0112.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/OBJ02623_PS3_K3_NIA0126.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/OBJ02974_PS3_K3_NIA0127.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/OBJ02975_PS3_K3_NIA0127.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/OBJ03150_PS3_K3_NIA0128.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/OBJ03497_PS3_K3A_NIA0144.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/OBJ03670_PS3_K3A_NIA0153.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/OBJ04020_PS3_K3A_NIA0169.png
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image/OBJ04021_PS3_K3A_NIA0169.png

# %%
# %cd /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image
# !pwd
# Out:
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image
# /content/drive/Shareddrives/msmg/level1/dataset/validation/building/image

# %%
# !mv *.txt ../annotation/

# %% [markdown]
# ## MMCV, PIL, numpy로 class별 masking 및 txt -> png 파일로 변환

# %%
# Check Pytorch installation
import torch, torchvision
print(torch.__version__, torch.cuda.is_available())
# Out:
# 1.11.0+cu113 False

# %%
# Install MMCV
# 런타임 -> 런타임 "다시 시작" 후 아래 수행. 
# !pip install mmcv-full -f https://download.openmmlab.com/mmcv/dist/cu111/torch1.10.0/index.html
# Out:
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu111/torch1.10.0/index.html
# Requirement already satisfied: mmcv-full in /usr/local/lib/python3.7/dist-packages (1.5.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from mmcv-full) (21.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from mmcv-full) (7.1.2)
# Requirement already satisfied: yapf in /usr/local/lib/python3.7/dist-packages (from mmcv-full) (0.32.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from mmcv-full) (3.13)
# Requirement already satisfied: opencv-python>=3 in /usr/local/lib/python3.7/dist-packages (from mmcv-full) (4.1.2.30)
# Requirement already satisfied: addict in /usr/local/lib/python3.7/dist-packages (from mmcv-full) (2.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from mmcv-full) (1.21.6)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->mmcv-full) (3.0.8)

# %% [markdown]
# - 0 -> background : [0, 0, 0]
# - 1 -> road : [255, 0, 255]
# - 2 -> building : [0, 0, 255]

# %%
import mmcv
import matplotlib.pyplot as plt
import os.path as osp
import numpy as np
from PIL import Image
import cv2

# convert dataset annotation to semantic segmentation map
data_root = '/content/drive/Shareddrives/msmg/level1/dataset/validation/building'
#img_dir = 'train'
ann_dir = 'annotation'

# define class and plaette for better visualization
classes = ('background', 'building')
palette = [[0, 0, 0], [0, 0, 255]]
# Out:
# No CUDA runtime is found, using CUDA_HOME='/usr/local/cuda'

# %%
for file in mmcv.scandir(osp.join(data_root, ann_dir), suffix='.txt'):
    seg_map = np.loadtxt(osp.join(data_root, ann_dir, file)).astype(np.uint8)
    seg_img = Image.fromarray(seg_map).convert('P')
    seg_img.putpalette(np.array(palette, dtype=np.uint8))
    seg_img.save(osp.join(data_root, ann_dir, file.replace('.txt', '.png')))

# %%
# Let's take a look at the segmentation map we got
import matplotlib.patches as mpatches

img = Image.open('/content/drive/Shareddrives/msmg/level1/dataset/validation/building/annotation/BLD00007_PS3_K3A_NIA0276.png')
plt.figure(figsize=(10, 10))
im = plt.imshow(np.array(img.convert('RGB')))

# create a patch (proxy artist) for every color 
patches = [mpatches.Patch(color=np.array(palette[i])/255., label=classes[i]) for i in range(2)]

# put those patched as legend-handles into the legend
plt.legend(handles=patches, bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., fontsize='large')

plt.show()
